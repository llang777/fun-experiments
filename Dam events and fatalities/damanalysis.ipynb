# %%
import pandas as pd
import folium
from folium import plugins

# Read the CSV file
df = pd.read_csv('Incidents_Search_Association_of_State_Dam_Safety.csv')

# Filter rows with latitude and longitude values
df = df[df['Latitude'].notna() & df['Longitude'].notna()]

# Create a Folium map centered around the first event's coordinates
map_center = [df['Latitude'].iloc[0], df['Longitude'].iloc[0]]
m = folium.Map(location=map_center, zoom_start=5)  # You can adjust the zoom level

# Create a MarkerCluster layer
marker_cluster = plugins.MarkerCluster().add_to(m)

# Add markers for each event with customized pop-up information
for index, row in df.iterrows():
    event_description = row['Incident Description']
    latitude = row['Latitude']
    longitude = row['Longitude']
    
    # Customize the pop-up content
    popup_text = f"<b>{event_description}</b><br>Latitude: {latitude}<br>Longitude: {longitude}"
    
    # Create a marker with the customized pop-up
    folium.Marker([latitude, longitude], popup=popup_text).add_to(marker_cluster)

# Save the map to an HTML file or display it
m.save('clustered_event_map.html')  # Save the map to an HTML file
m  # Uncomment this line to display the map in a Jupyter Notebook
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85cf8636b90039420f0fe0666a6ef18d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85cf8636b90039420f0fe0666a6ef18d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85cf8636b90039420f0fe0666a6ef18d = L.map(
#                 &quot;map_85cf8636b90039420f0fe0666a6ef18d&quot;,
#                 {
#                     center: [32.2595, -90.4113],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11f7f7eb173dbec74bafd921acba306c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_11f7f7eb173dbec74bafd921acba306c.addTo(map_85cf8636b90039420f0fe0666a6ef18d);
#
#
#             var marker_cluster_3479a62757707b1c6d8c2d0bcfb1f9d4 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_f63034f618dcf2384a64064b05673050 = L.marker(
#                 [32.2595, -90.4113],
#                 {}
#             ).addTo(marker_cluster_3479a62757707b1c6d8c2d0bcfb1f9d4);
#
#
#         var popup_58b0659a0cb0ef64e5cca6f6cb05a809 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4b2ac7543fe4826941549ac3b15a4206 = $(`&lt;div id=&quot;html_4b2ac7543fe4826941549ac3b15a4206&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Erosion of backslope due to tailwater conditions and animal activity.  Breached area appeared to be a collapsed animal den.&lt;/b&gt;&lt;br&gt;Latitude: 32.2595&lt;br&gt;Longitude: -90.4113&lt;/div&gt;`)[0];
#                 popup_58b0659a0cb0ef64e5cca6f6cb05a809.setContent(html_4b2ac7543fe4826941549ac3b15a4206);
#
#
#
#         marker_f63034f618dcf2384a64064b05673050.bindPopup(popup_58b0659a0cb0ef64e5cca6f6cb05a809)
#         ;
#
#
#
#
#             var marker_d975325e34dc16c43c125447f97e78e0 = L.marker(
#                 [33.6217, -81.2333],
#                 {}
#             ).addTo(marker_cluster_3479a62757707b1c6d8c2d0bcfb1f9d4);
#
#
#         var popup_740edbd8dba6a6d18ea7686d1870074a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04b47fc138a0377f6d06c45d63ad1723 = $(`&lt;div id=&quot;html_04b47fc138a0377f6d06c45d63ad1723&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Heavy rains-as much as 16 inches caused several dams to overtop and fail.&lt;/b&gt;&lt;br&gt;Latitude: 33.6217&lt;br&gt;Longitude: -81.2333&lt;/div&gt;`)[0];
#                 popup_740edbd8dba6a6d18ea7686d1870074a.setContent(html_04b47fc138a0377f6d06c45d63ad1723);
#
#
#
#         marker_d975325e34dc16c43c125447f97e78e0.bindPopup(popup_740edbd8dba6a6d18ea7686d1870074a)
#         ;
#
#
#
#
#             var marker_cc9a150aca16bf925b39ba5d51468c50 = L.marker(
#                 [37.8231, -90.8224],
#                 {}
#             ).addTo(marker_cluster_3479a62757707b1c6d8c2d0bcfb1f9d4);
#
#
#         var popup_f95cfd0f5f0767af5e70035a87dfd94d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bba78ae7082bd31800df9d44219efb98 = $(`&lt;div id=&quot;html_bba78ae7082bd31800df9d44219efb98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;test&lt;/b&gt;&lt;br&gt;Latitude: 37.8231&lt;br&gt;Longitude: -90.8224&lt;/div&gt;`)[0];
#                 popup_f95cfd0f5f0767af5e70035a87dfd94d.setContent(html_bba78ae7082bd31800df9d44219efb98);
#
#
#
#         marker_cc9a150aca16bf925b39ba5d51468c50.bindPopup(popup_f95cfd0f5f0767af5e70035a87dfd94d)
#         ;
#
#
#
#
#             var marker_7bf9575022d088a4109a182151530a39 = L.marker(
#                 [38.235, -103.281],
#                 {}
#             ).addTo(marker_cluster_3479a62757707b1c6d8c2d0bcfb1f9d4);
#
#
#         var popup_01e4bb5ec35783b31c6540d979f6d99c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_14fd68086bf68c7b46dc86ec2b7dca0b = $(`&lt;div id=&quot;html_14fd68086bf68c7b46dc86ec2b7dca0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;New active seepage along an outlet conduit, creating voids where none were before.&lt;/b&gt;&lt;br&gt;Latitude: 38.235&lt;br&gt;Longitude: -103.281&lt;/div&gt;`)[0];
#                 popup_01e4bb5ec35783b31c6540d979f6d99c.setContent(html_14fd68086bf68c7b46dc86ec2b7dca0b);

# %%
import pandas as pd
import folium
from folium import plugins

# Read the CSV file
df = pd.read_csv('Incidents_Search_Association_of_State_Dam_Safety.csv')

# Filter rows with latitude, longitude, and valid fatalities values
df = df[df['Latitude'].notna() & df['Longitude'].notna() & df['Fatalities (Number)'].notna()]

# Create a Folium map centered around the first event's coordinates
map_center = [df['Latitude'].iloc[0], df['Longitude'].iloc[0]]
m = folium.Map(location=map_center, zoom_start=5)  # You can adjust the zoom level

# Define a color scale for fatalities
def color_scale(fatalities):
    if fatalities == 'unknown':
        return 'gray'  # Color for unknown fatalities
    fatalities = int(fatalities)  # Convert fatalities to integer
    if fatalities == 0:
        return 'green'  # No fatalities
    elif fatalities < 10:
        return 'orange'  # Low fatalities
    else:
        return 'red'  # High fatalities

# Create a MarkerCluster layer
marker_cluster = plugins.MarkerCluster().add_to(m)

# Add markers for each event with customized pop-up information and color-coded by fatalities
for index, row in df.iterrows():
    event_description = row['Incident Description']
    latitude = row['Latitude']
    longitude = row['Longitude']
    fatalities = row['Fatalities (Number)']
    
    # Customize the pop-up content including fatalities
    popup_text = f"<b>{event_description}</b><br>Latitude: {latitude}<br>Longitude: {longitude}<br>Fatalities: {fatalities}"
    
    # Create a marker with the customized pop-up and color-coded icon
    folium.Marker([latitude, longitude], 
                  popup=popup_text,
                  icon=folium.Icon(color=color_scale(fatalities), icon='info-sign')
                 ).add_to(marker_cluster)

# Save the map to an HTML file or display it
m.save('clustered_event_map_with_fatalities.html')  # Save the map to an HTML file
m  # Uncomment this line to display the map in a Jupyter Notebook
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85961c3efb29c66e30193d68d9e7913a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85961c3efb29c66e30193d68d9e7913a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85961c3efb29c66e30193d68d9e7913a = L.map(
#                 &quot;map_85961c3efb29c66e30193d68d9e7913a&quot;,
#                 {
#                     center: [32.2595, -90.4113],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2004d84f4805939b516aee0658d9650e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2004d84f4805939b516aee0658d9650e.addTo(map_85961c3efb29c66e30193d68d9e7913a);
#
#
#             var marker_cluster_f6cce48cbfc7562eb505ea3381bcc0cc = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_0db427f6c633c27221d5d3d42049d060 = L.marker(
#                 [32.2595, -90.4113],
#                 {}
#             ).addTo(marker_cluster_f6cce48cbfc7562eb505ea3381bcc0cc);
#
#
#             var icon_b87b67536bb87b2fde84fe1337a55713 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0db427f6c633c27221d5d3d42049d060.setIcon(icon_b87b67536bb87b2fde84fe1337a55713);
#
#
#         var popup_f4b412a640e9d0559f8fdef00f8479e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd8b4e0bf8ce0a3ec0b4aa06b743d924 = $(`&lt;div id=&quot;html_dd8b4e0bf8ce0a3ec0b4aa06b743d924&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Erosion of backslope due to tailwater conditions and animal activity.  Breached area appeared to be a collapsed animal den.&lt;/b&gt;&lt;br&gt;Latitude: 32.2595&lt;br&gt;Longitude: -90.4113&lt;br&gt;Fatalities: 0&lt;/div&gt;`)[0];
#                 popup_f4b412a640e9d0559f8fdef00f8479e9.setContent(html_dd8b4e0bf8ce0a3ec0b4aa06b743d924);
#
#
#
#         marker_0db427f6c633c27221d5d3d42049d060.bindPopup(popup_f4b412a640e9d0559f8fdef00f8479e9)
#         ;
#
#
#
#
#             var marker_b74f283dd5fc3a2cd9a2ce02b89d19f0 = L.marker(
#                 [37.2835, -77.2109],
#                 {}
#             ).addTo(marker_cluster_f6cce48cbfc7562eb505ea3381bcc0cc);
#
#
#             var icon_a1e4cec99a14fb6e57661f8496ee2b60 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b74f283dd5fc3a2cd9a2ce02b89d19f0.setIcon(icon_a1e4cec99a14fb6e57661f8496ee2b60);
#
#
#         var popup_3e4699e07defc949a9eb91cba3d4d5a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_95224524501a2fa338a36dae9e0ece74 = $(`&lt;div id=&quot;html_95224524501a2fa338a36dae9e0ece74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;nan&lt;/b&gt;&lt;br&gt;Latitude: 37.2835&lt;br&gt;Longitude: -77.2109&lt;br&gt;Fatalities: 0&lt;/div&gt;`)[0];
#                 popup_3e4699e07defc949a9eb91cba3d4d5a7.setContent(html_95224524501a2fa338a36dae9e0ece74);
#
#
#
#         marker_b74f283dd5fc3a2cd9a2ce02b89d19f0.bindPopup(popup_3e4699e07defc949a9eb91cba3d4d5a7)
#         ;
#
#
#
#
#             var marker_16ad18ef37196291f5c0aa5d92228384 = L.marker(
#                 [47.541, -92.3108],
#                 {}
#             ).addTo(marker_cluster_f6cce48cbfc7562eb505ea3381bcc0cc);
#
#
#             var icon_73314af43b6e05d9a04638f2d25eb838 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_16ad18ef37196291f5c0aa5d92228384.setIcon(icon_73314af43b6e05d9a04638f2d25eb838);
#
#
#         var popup_b333bdf9f6b211efe71f3a061c315fc5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %%
import pandas as pd
import folium
from folium import plugins
import numpy as np

# Read the CSV file
df = pd.read_csv('Incidents_Search_Association_of_State_Dam_Safety.csv')

# Filter rows with latitude and longitude values
df = df[df['Latitude'].notna() & df['Longitude'].notna()]

# Create a Folium map centered around the first event's coordinates
map_center = [df['Latitude'].iloc[0], df['Longitude'].iloc[0]]
m = folium.Map(location=map_center, zoom_start=5)  # You can adjust the zoom level

# Create a list of (latitude, longitude) pairs
locations = list(zip(df['Latitude'], df['Longitude']))

# Create a heatmap layer
heatmap = plugins.HeatMap(locations, radius=20)

# Add the heatmap layer to the map
heatmap.add_to(m)

# Save the map to an HTML file or display it
m.save('event_heatmap.html')  # Save the map to an HTML file
m  # Uncomment this line to display the map in a Jupyter Notebook
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59a54cab3255093cce718b8f47709d8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59a54cab3255093cce718b8f47709d8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59a54cab3255093cce718b8f47709d8b = L.map(
#                 &quot;map_59a54cab3255093cce718b8f47709d8b&quot;,
#                 {
#                     center: [32.2595, -90.4113],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de7a4fe823ceffc7639e595f9b0e5e1d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_de7a4fe823ceffc7639e595f9b0e5e1d.addTo(map_59a54cab3255093cce718b8f47709d8b);
#
#
#             var heat_map_e2bd22d584c54abc4cfbbbe327fbdced = L.heatLayer(
#                 [[32.2595, -90.4113], [33.6217, -81.2333], [37.8231, -90.8224], [38.235, -103.281], [37.2835, -77.2109], [47.541, -92.3108], [31.4051, -105.818], [31.4051, -105.818], [37.4703, -106.766], [30.9806, -89.6881], [30.9806, -89.6881], [30.9822, -89.6875], [37.5636, -78.403], [39.4039, -86.1231], [43.44, -96.6083], [30.8889, -94.4003], [30.9145, -97.1999], [0.0, 0.0], [0.0, 0.0], [26.137, -98.334], [39.6057, -104.874], [30.7896, -95.5282], [26.3531, -97.4907], [35.029, -78.981], [41.1536, -75.5775], [0.0, 0.0], [43.1507, -72.1569], [0.0, 0.0], [32.2346, -95.7774], [42.5379, -99.0005], [37.0676, -119.49], [39.9511, -80.1628], [0.0, 0.0], [0.0, 0.0], [40.0784, -104.564], [0.0, 0.0], [40.6, -105.836], [27.6267, -97.3483], [38.4617, -75.735], [41.1969, -74.4412], [30.3715, -95.3387], [44.2506, -74.2942], [44.1, -73.5117], [39.9986, -105.198], [40.0028, -105.206], [32.0011, -95.9015], [30.1124, -97.277], [42.3211, -74.2325], [42.3322, -74.2478], [31.548, -96.901], [34.1114, -79.3352], [34.1117, -79.335], [0.0, 0.0], [30.4819, -94.7734], [30.4819, -94.7734], [30.4819, -94.7734], [37.5078, -77.5312], [36.7433, -79.875], [37.5961, -106.667], [42.5819, -89.7745], [40.6822, -94.7127], [40.6822, -94.7127], [42.8605, -89.5358], [37.8136, -108.353], [42.745, -74.7603], [35.0773, -77.9099], [34.1555, -88.4259], [38.8845, -84.7429], [33.3924, -95.6941], [41.7528, -75.9547], [41.7528